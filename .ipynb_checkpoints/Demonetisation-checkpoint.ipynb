# %% [markdown]
# # Exploratory Data Analysis of ~20k tweets from 9/11/2016 to 12/12/2016.
#
#    Today Demonetisation is something that has affected every single person in the country, in a mostly direct way. Though are no official stats on the impact it had on the economy in the last 40 days or so I thought it would be interesting to explore the general sentiment on Twitter, to understand what folks from diverse walks of life think.
#
#   It was easier said than done. Depending on the way you see it, Twitter data is either entirely usesless or is very difficult to classify. Though I certainly dont think Twitter as the gold standard of the country's opinion, I still valid  opinions are voiced there and it's worth taking a look.
#
#  I compiled close to 20,000 tweets, from 9/11/2016 to 12/12/2016, classified sentiments using Indico.io's sentiment classifier and also hand classified a few tweets written in Hinglish.
#
#  These were the questions I was trying to get answered with these tweets:
#  * What was the average sentiment over these 34 days.
#  * A word-cloud of both positive/negative tweets.
#  * How did sentiments change over a period of time in India's top 10 cities by population. What were folks outside india saying and how did that change over time?
#  * Where did the most positive tweets come from? Where did the most negative tweets come from?
#  * What were Twitter's "influencers" saying about this move? And how did that change over time?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import indicoio as indico
import matplotlib as mpl
import matplotlib.pyplot as plt
import collections
from collections import OrderedDict
import plotly
from wordcloud import WordCloud
import re
import nltk
from nltk.corpus import stopwords
import string
from scipy.misc import imread
import geopy
from geopy.geocoders import Nominatim


# %matplotlib inline
sns.set(style="whitegrid")

# %%
df = pd.read_csv('tweets.csv')

# %%
df.drop(['Unnamed: 0'], axis = 1, inplace = True, errors = 'ignore')

# %%
df.columns
# Out:
# Index(['user id', 'name', 'handle', 'date', 'retweets', 'favorites', 'text',
#        'id', 'permalink', 'language', 'followers_count', 'location',
#        'sentiment'],
#       dtype='object')

# %%
df.head()
# Out:
#         user id             name           handle                 date  \
# 0  7.108627e+17        The gamer  VenkateshaPanc2  2016-11-09 23:38:24
# 1  7.291956e+07   Uma Kant Singh  umakantsingh_in  2016-11-09 23:38:42
# 2  2.381901e+08  Antony bothagar   Antonybothagar  2016-11-09 23:38:46
# 3  2.433278e+09  Abhishek Sharma    skyneeldotcom  2016-11-09 23:38:53
# 4  3.246635e+09     abdul rahman  RahmanAbdul2603  2016-11-09 23:39:21
#
#    retweets  favorites                                               text  \
# 0       0.0        0.0  If common man is supporting the decision why c...
# 1       0.0        0.0  #DeMonetisation,Not govt of common man,PM who ...
# 2       0.0        1.0  I am already suffering to get changes for ₹ 10...
# 3       1.0        1.0  #APPSC #Recruitment 2016 – Apply Online for 98...
# 4       0.0        0.0  #DeMonetisation almst everybody knows fr a mar...
#
#              id                                          permalink language  \
# 0  7.964142e+17  https://twitter.com/VenkateshaPanc2/status/796...       en
# 1  7.964142e+17  https://twitter.com/umakantsingh_in/status/796...       en
# 2  7.964142e+17  https://twitter.com/Antonybothagar/status/7964...       en
# 3  7.964143e+17  https://twitter.com/skyneeldotcom/status/79641...       en
# 4  7.964144e+17  https://twitter.com/RahmanAbdul2603/status/796...       en
#
#    followers_count           location  sentiment
# 0              6.0      Indore, India   0.712256
# 1            455.0          New Delhi   0.433632
# 2             76.0                NaN   0.844959
# 3           6288.0                NaN   0.568757
# 4             48.0  Saharanpur, India   0.080881

# %% [markdown]
# ## Lets first look at overall sentiment over the course of these 34 days.

# %%
## Get average sentiment for each week. For that, return Dataframes for each week.  
def search(df, *words):  #1
    return df[np.logical_or.reduce([df['date'].str.contains(word) for word in words])]
week1 = search(df,"2016-11-09","2016-11-10","2016-11-11","2016-11-12","2016-11-13","2016-11-14","2016-11-15","2016-11-16")

# %% [markdown]
# ## Maybe we can look at the data in a slightly granular way. Mean sentiment for each day.
# ### A scatter plot would help.

# %%
day_count = df['date'].unique().tolist()
day_count = [i.split(' ', 1)[0] for i in day_count] #remove time-stamps.
day_count = list(OrderedDict.fromkeys(day_count))
mean_sentiment_each_day = []
for i in range(0, 34):
    mean_sentiment_each_day.append((search(df,day_count[i])['sentiment'].mean())*100) ## 
print(mean_sentiment_each_day)
# Out:
# [53.136832903225809, 52.921829355149171, 50.774063636363628, 48.179133333333333, 51.16975626598466, 53.476719999999986, 50.039012499999998, 51.350087678339818, 51.913394965986392, 47.948271313672933, 52.364179829545456, 48.739098203592818, 52.228293522267208, 48.062430821917815, 51.705255329949239, 49.913779966887411, 47.832414985994397, 55.673494999999981, 39.815657142857141, 49.845762499999999, 51.119342201834861, 45.726437500000003, 45.608518881118883, 47.380484290540537, 49.258282573099414, 50.329545744680857, 47.727182420091324, 49.08963748458693, 47.717728712871285, 44.266404385964911, 47.598505787781356, 48.914792917166871, 48.785451050679853, 47.431779556898285]

# %%
## Create a new dataframe for plotting it as a scatter plot. 
mean_sentiment_df = pd.DataFrame()
mean_sentiment_df['day_count'] = list(range(0,34))
mean_sentiment_df['mean_sentiment'] = mean_sentiment_each_day
mean_sentiment_df.head()
# Out:
#    day_count  mean_sentiment
# 0          0       53.136833
# 1          1       52.921829
# 2          2       50.774064
# 3          3       48.179133
# 4          4       51.169756

# %%
sns.lmplot(x="day_count", y="mean_sentiment", data=mean_sentiment_df)

# %% [markdown]
# ### There's definitely a decline in sentiment over 34 days. It would also be interesting to see how many tweets were in each interval.

# %%
sns.distplot((df['sentiment']*100), bins=10, kde=False, rug=True);

# %% [markdown]
# ## Let's try and visualise a word cloud for tweets.

# %%
# a dataframe of positive and negative with just the 'text' and 'sentiment' column.
only_text_and_sentiments = df[['text','sentiment']]
positive_tweets = only_text_and_sentiments[only_text_and_sentiments['sentiment'] > 0.5]
positive_tweets = positive_tweets.sort_values('sentiment',ascending=False)
negative_tweets = only_text_and_sentiments[only_text_and_sentiments['sentiment'] < 0.5]
negative_tweets = negative_tweets.sort_values('sentiment',ascending=False)

# %% [markdown]
# ### A wordcloud of all tweets masked on a map of India.

# %%
all_words = ''
intab = string.punctuation
outtab = "                                "
trantab = str.maketrans(intab, outtab)
for val in only_text_and_sentiments["text"]:
    text = val.lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"pic.twitter\S+", "",text)
    text = text.translate(trantab)
    tokens = nltk.word_tokenize(text)
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    for words in tokens:
        all_words = all_words + words + ' '
all_wordcloud = WordCloud(width=900, height=500).generate(all_words)


plt.figure( figsize=(30,20), facecolor='k')
plt.imshow(all_wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# Mask it over a map of india. For 'em data nerds.
india_map = imread("india-map.png")
wc = WordCloud(width=900, height=500,background_color="white", max_words=2000, mask=india_map)
wc.generate(all_words)

plt.figure(figsize=(10,10))
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## Now, to visualise sentiment over a period of time in each major city in the country. We'll plot changes in sentiment for india's top 10 cities over a period of time.

# %%
# Top cities of india by GDP.
top_10_cities = ['Mumbai','Delhi','Kolkata','Bengaluru','Hyderabad','Chennai','Ahmedabad','Pune','Surat','Visakhapatnam']
cities_combination = ["Mumbai","Bombay","Bombay, India","Mumbai, India","mumbai","Bangalore,India","Bengaluru, India",
                      "B'lore","Bengaluru","Bangalore","Bengaluru South, India","Gurgaon, India","Hyderabad, India","Hyderabad","Delhi, India",
                      "New Delhi, India","Delhi","New Delhi","Noida, India","Noida","Chennai, India",
                      "Chennai","Madras, India","Madras","Kolkata, India","Kolkata",
                      "Ahmedabad, India","Ahmedabad","Pune, India","Pune",
                      "Surat, India","Surat","Visakhapatnam, India","Visakhapatnam"]

top_10_df = df[df['location'].isin(cities_combination)]
top_10_df.head(2)
# Out:
#        user id            name           handle                 date  \
# 1   72919562.0  Uma Kant Singh  umakantsingh_in  2016-11-09 23:38:42
# 8  589197875.0    Common Sense   CommonSense___  2016-11-09 23:39:50
#
#    retweets  favorites                                               text  \
# 1       0.0        0.0  #DeMonetisation,Not govt of common man,PM who ...
# 8       0.0        0.0  For Indian fiberals anything is war & everythi...
#
#              id                                          permalink language  \
# 1  7.964142e+17  https://twitter.com/umakantsingh_in/status/796...       en
# 8  7.964145e+17  https://twitter.com/CommonSense___/status/7964...       en
#
#    followers_count     location  sentiment
# 1            455.0    New Delhi   0.433632
# 8            244.0  Pune, India   0.713806

# %%
# for index, row in top_10_df.iterrows():
#     if(row['location'] in "Mumbai|Bombay|Bombay, India|Mumbai, India|mumbai"):
#         top_10_df.set_value(index,'location',"Mumbai, India")
#     elif(row['location'] in "Bangalore,India|Bengaluru, India|B'lore|Bengaluru|Bangalore|Bengaluru South, India"):
#         top_10_df.set_value(index,'location',"Bengaluru, India")
#     elif(row['location'] in "Hyderabad, India|Hyderabad|hyderabad"):
#         top_10_df.set_value(index,'location',"Hyderabad, India")
#     elif(row['location'] in "Delhi, India|New Delhi, India|Delhi|New Delhi"):
#         top_10_df.set_value(index,'location',"Hyderabad, India")
#     elif(row['location'] in "Gurgaon, India|gurgaon|r^gurugram"):
#         top_10_df.set_value(index,'location',"Gurgaon, India")
#     elif(row['location'] in "Noida, India|Noida"):
#         top_10_df.set_value(index,'location',"Noida, India")
#     elif(row['location'] in "Chennai, India|Chennai|Madras, India|Madras"):
#         top_10_df.set_value(index,'location',"Chennai, India")
#     elif(row['location'] in "Kolkata, India|Kolkata|Calcutta|Calcutta, India"):
#          top_10_df.set_value(index,'location',"Kolkata, India")
#     elif(row['location'] in "Ahmedabad, India|Ahmedabad"):
#          top_10_df.set_value(index,'location',"Ahmedabad, India")
#     elif(row['location'] in "Pune, India|Pune"):
#          top_10_df.set_value(index,'location',"Pune, India")
#     elif(row['location'] in "Surat, India|Surat"):
#          top_10_df.set_value(index,'location',"Surat, India")
#     elif(row['location'] in "Visakhapatnam, India|Visakhapatnam"):
#          top_10_df.set_value(index,'location',"Visakhapatnam, India")
    
    
# top_10_df[top_10_df['location'] == "Bengaluru, India"]

# %%
## Get lat/lng for each of these locations and add them to the dataframe. 
lat = []
long = []
geolocator = Nominatim()
for location in (top_10_df['location'].unique()):
    lat.append((geolocator.geocode(location)).latitude)
    long.append((geolocator.geocode(location)).longitude)
print(len(lat))
print(len(long))
# Out:
# 32
# 32

# %%
lat_long_df = pd.DataFrame()
lat_long_df['location'] = top_10_df['location'].unique()
lat_long_df['latitude'] = lat
lat_long_df['longitude'] = long

lat_long_df.head()
# Out:
#            location   latitude  longitude
# 0         New Delhi  28.613897  77.215956
# 1       Pune, India  18.643958  73.932568
# 2         Hyderabad  17.361623  78.474731
# 3  Bengaluru, India  12.979120  77.591300
# 4  Hyderabad, India  17.361623  78.474731

# %%
top_10_df.shape[0]
# Out:
# 4292

# %%
top_df = pd.merge(top_10_df, lat_long_df, on='location', how='outer')

# %%
top_df.head()
# Out:
#        user id            name           handle                 date  \
# 0   72919562.0  Uma Kant Singh  umakantsingh_in  2016-11-09 23:38:42
# 1   72919562.0  Uma Kant Singh  umakantsingh_in  2016-11-09 23:43:28
# 2  149851066.0     Neeraj Goel           nginc5  2016-11-09 23:47:11
# 3  149851066.0     Neeraj Goel           nginc5  2016-11-09 23:48:22
# 4  149851066.0     Neeraj Goel           nginc5  2016-11-09 23:49:14
#
#    retweets  favorites                                               text  \
# 0       0.0        0.0  #DeMonetisation,Not govt of common man,PM who ...
# 1       0.0        1.0  #DeMonetisation,finally to hit very hard the d...
# 2       0.0        0.0  #DeMonetisation what jaitly talking about cash...
# 3       0.0        0.0  #DeMonetisation with payment banks otherwise h...
# 4       0.0        0.0  @KejriwalFanCIub shut up income tax ke chor #D...
#
#              id                                          permalink language  \
# 0  7.964142e+17  https://twitter.com/umakantsingh_in/status/796...       en
# 1  7.964154e+17  https://twitter.com/umakantsingh_in/status/796...       en
# 2  7.964164e+17  https://twitter.com/nginc5/status/796416358409...       en
# 3  7.964167e+17  https://twitter.com/nginc5/status/796416655777...       en
# 4  7.964169e+17  https://twitter.com/nginc5/status/796416876746...       en
#
#    followers_count   location  sentiment   latitude  longitude
# 0            455.0  New Delhi   0.433632  28.613897  77.215956
# 1            455.0  New Delhi   0.954710  28.613897  77.215956
# 2            705.0  New Delhi   0.555005  28.613897  77.215956
# 3            705.0  New Delhi   0.420334  28.613897  77.215956
# 4            705.0  New Delhi   0.418685  28.613897  77.215956

# %%
top_df.shape[0]
# Out:
# 4292

# %%
top_df.tail()
# Out:
#            user id                 name           handle                 date  \
# 4287  1.476994e+07            sriks6711        sriks6711  2016-12-10 00:47:19
# 4288  1.895945e+09                અધીરો           kunj09  2016-12-01 22:58:41
# 4289  2.631305e+08        Sunil Banthia     sunilbanthia  2016-12-06 21:21:17
# 4290  7.951576e+08  breath taking beast  heartbreakerMAS  2016-12-11 05:11:59
# 4291  8.916728e+07        Utpal Ruparel        utpal2323  2016-12-12 12:10:32
#
#       retweets  favorites                                               text  \
# 4287       0.0        0.0  There can be many mistakes in the implementati...
# 4288       0.0        0.0  @AbhinavAAP @ArvindKejriwal yeah after #DeMone...
# 4289       0.0        0.0  you can’t make an omelette without breaking eg...
# 4290       0.0        0.0  We are resilience by force and not by choice M...
# 4291       0.0        0.0  @AshwiniBJP @BeingSalmanKhan @iamsrk @amir_kha...
#
#                 id                                          permalink  \
# 4287  8.073031e+17  https://twitter.com/sriks6711/status/807303128...
# 4288  8.043767e+17  https://twitter.com/kunj09/status/804376686519...
# 4289  8.061641e+17  https://twitter.com/sunilbanthia/status/806164...
# 4290  8.077321e+17  https://twitter.com/heartbreakerMAS/status/807...
# 4291  8.081998e+17  https://twitter.com/utpal2323/status/808199843...
#
#      language  followers_count       location  sentiment   latitude  longitude
# 4287       en            257.0  Visakhapatnam   0.179993  17.723128  83.301284
# 4288       en             80.0          Surat   0.438341  21.186461  72.808128
# 4289       en            264.0          Surat   0.781385  21.186461  72.808128
# 4290       en             96.0          Surat   0.278424  21.186461  72.808128
# 4291       en            282.0          Surat   0.881988  21.186461  72.808128

# %%
## Now to create a neat heatmap over time.
num_colors = 9
shapefile = 'INDIA.shp'
values = top_df['sentiment']
cm = plt.get_cmap('Greens')
scheme = [cm(i / num_colors) for i in range(num_colors)]
bins = np.linspace(values.min(), values.max(), num_colors)
top_df['bin'] = np.digitize(values, bins) - 1
top_df.sort_values('bin', ascending=False).head(10)
# Out:
#            user id              name          handle                 date  \
# 3455  1.200892e+08         siddharth        sidnokid  2016-11-13 02:33:35
# 4073  8.453813e+07      santoshokali     Santy_24Dec  2016-12-04 00:43:58
# 3436  1.874803e+08       Rahul Singh  rahulsingh0804  2016-11-09 23:58:12
# 2903  5.884142e+08    Pramod K Dubey       p_dubey21  2016-12-05 23:20:32
# 3444  5.170629e+07       anju juneja      anjujuneja  2016-11-10 01:42:01
# 284   5.520900e+07    Ashok Bijalwan       AshTheWiz  2016-12-02 00:40:50
# 1018  1.348688e+09               Ram   ram_gurumukhi  2016-11-22 02:15:07
# 1717  3.049938e+09      Veidehi Gite        Veidehii  2016-12-11 03:12:07
# 1017  1.348688e+09               Ram   ram_gurumukhi  2016-11-22 02:13:26
# 4069  1.347880e+08  Renukesh Bingeri       RenukeshB  2016-12-01 04:50:35
#
#       retweets  favorites                                               text  \
# 3455       0.0        0.0  #DeMonetisation has developed  d faith dat i c...
# 4073       0.0        2.0  Toll collection is back. stuck in for same mor...
# 3436       0.0        0.0  #DeMonetisation. Only now everybody can relate...
# 2903       1.0        0.0  MUST WATCH  Discussion in Mumbai Local Train o...
# 3444       3.0        4.0  Today my uncle passed away. my father and whol...
# 284        0.0        0.0  A layman's guide to #demonetisation on the roa...
# 1018       0.0        0.0  @Virendrsehwag here is a must read article abo...
# 1717       0.0        0.0  @piyasreedg This just made my day  and some fa...
# 1017      17.0       28.0  Extremely happy for Peaceful Kashmir. Thanks @...
# 4069       2.0        1.0  Very Nice article Sir @VishweshwarBhat real si...
#
#                 id                                          permalink  \
# 3455  7.975454e+17  https://twitter.com/sidnokid/status/7975454001...
# 4073  8.051280e+17  https://twitter.com/Santy_24Dec/status/8051279...
# 3436  7.964191e+17  https://twitter.com/rahulsingh0804/status/7964...
# 2903  8.058317e+17  https://twitter.com/p_dubey21/status/805831739...
# 3444  7.964453e+17  https://twitter.com/anjujuneja/status/79644526...
# 284   8.044024e+17  https://twitter.com/AshTheWiz/status/804402395...
# 1018  8.008022e+17  https://twitter.com/ram_gurumukhi/status/80080...
# 1717  8.077020e+17  https://twitter.com/Veidehii/status/8077019581...
# 1017  8.008018e+17  https://twitter.com/ram_gurumukhi/status/80080...
# 4069  8.041029e+17  https://twitter.com/RenukeshB/status/804102857...
#
#      language  followers_count          location  sentiment   latitude  \
# 3455       en            151.0             Delhi   0.997693  28.651718
# 4073       en             64.0         Bengaluru   0.892110  12.979120
# 3436       en             46.0             Delhi   0.920488  28.651718
# 2903       en           1508.0  New Delhi, India   0.918767  28.613897
# 3444       en           4402.0             Delhi   0.918933  28.651718
# 284        en            151.0         New Delhi   0.907763  28.613897
# 1018       en            341.0  Hyderabad, India   0.972694  17.361623
# 1717       en          22196.0     Mumbai, India   0.912345  18.932186
# 1017       en            341.0  Hyderabad, India   0.959284  17.361623
# 4069       en            231.0         Bengaluru   0.976001  12.979120
#
#       longitude  bin
# 3455  77.221939    8
# 4073  77.591300    7
# 3436  77.221939    7
# 2903  77.215956    7
# 3444  77.221939    7
# 284   77.215956    7
# 1018  78.474731    7
# 1717  72.830834    7
# 1017  78.474731    7
# 4069  77.591300    7

# %%
mpl.style.use('map')
fig = plt.figure(figsize=(22, 12))
ax = fig.add_subplot(111, axisbg='w', frame_on=False)
m = Basemap(lon_0=0, projection='robin')
m.drawmapboundary(color='w')
m.readshapefile(shapefile, 'units', color='#444444', linewidth=.2)
for info, shape in zip(m.units_info, m.units):
    print(info, shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/style/core.py in use(style)
#      83             try:
# ---> 84                 rc = rc_params_from_file(style, use_default_template=False)
#      85                 mpl.rcParams.update(rc)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#    1106     """
# -> 1107     config_from_file = _rc_params_in_file(fname, fail_on_error)
#    1108
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/__init__.py in _rc_params_in_file(fname, fail_on_error)
#    1023     rc_temp = {}
# -> 1024     with _open_file_or_url(fname) as fd:
#    1025         try:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/contextlib.py in __enter__(self)
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/__init__.py in _open_file_or_url(fname)
#    1008             encoding = "utf-8"
# -> 1009         with io.open(fname, encoding=encoding) as f:
#    1010             yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'map'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-215-98bf47a9b8f9> in <module>()
# ----> 1 mpl.style.use('map')
#       2 fig = plt.figure(figsize=(22, 12))
#       3 ax = fig.add_subplot(111, axisbg='w', frame_on=False)
#       4 m = Basemap(lon_0=0, projection='robin')
#       5 m.drawmapboundary(color='w')
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/style/core.py in use(style)
#      88                        "not a valid URL or path. See `style.available` for "
#      89                        "list of available styles.")
# ---> 90                 raise IOError(msg % style)
#      91
#      92
#
# OSError: 'map' not found in the style library and input is not a valid URL or path. See `style.available` for list of available styles.

# %%
influencers_df = df[df['followers_count'] > 10000]

# %%
influencers_df.head()
# Out:
#          user id              name       handle                 date  \
# 16  3.036331e+08      Reddit India  redditindia  2016-11-09 23:40:42
# 22  8.946304e+08  Bhubaneswar Buzz     BBSRBuzz  2016-11-09 23:41:42
# 50  1.341601e+08     S.Ranganathan      rangats  2016-11-09 23:45:30
# 57  1.341601e+08     S.Ranganathan      rangats  2016-11-09 23:46:03
# 82  3.683007e+09       MyVoteToday  myvotetoday  2016-11-09 23:49:23
#
#     retweets  favorites                                               text  \
# 16     125.0       99.0  RK Laxman's Cartoon from 1978 when #demonetisa...
# 22       0.0        3.0  @agrawalakhil did you realize there was a cric...
# 50       2.0        0.0  @narendramodi yesterday u shud have ordered cl...
# 57       2.0        1.0  @narendramodi #DeMonetisation becomes a mocker...
# 82       7.0       17.0  Law prohibits live coverage of terrorists oper...
#
#               id                                          permalink language  \
# 16  7.964147e+17  https://twitter.com/redditindia/status/7964147...       en
# 22  7.964150e+17  https://twitter.com/BBSRBuzz/status/7964149777...       en
# 50  7.964159e+17  https://twitter.com/rangats/status/79641593781...       en
# 57  7.964161e+17  https://twitter.com/rangats/status/79641607491...       en
# 82  7.964169e+17  https://twitter.com/myvotetoday/status/7964169...       en
#
#     followers_count                    location  sentiment
# 16          27232.0                       India   0.596269
# 22          21089.0  Bhubaneswar, Odisha, India   0.903619
# 50          14222.0                      Madras   0.784518
# 57          14222.0                      Madras   0.198267
# 82         448314.0                         NaN   0.179144

# %%
influencers_df.to_csv("influencers.csv")

# %%
influencers_df['handle'].unique()
# Out:
# array(['redditindia', 'BBSRBuzz', 'rangats', 'myvotetoday',
#        'prasarbharati', 'mumbaiheritage', 'kvQuote', 'vccircle',
#        'TheHindu', 'Vidyut', 'viralbollywood', 'trendinaliaIN', 'HTMumbai',
#        'Nir_27', 'Drpayal_1289', 'ExSecular', 'ScrewedbyState',
#        'MusafirNamah', 'mid_day', 'IgnitedBrain', 'frozenmusik',
#        'behindwoods', 'abpnewstv', 'autocarindiamag', 'manoramaonline',
#        'AshDubey_', 'moneycontrolcom', 'AAPInNews', 'msrbpl',
#        'vinaydokania', 'dhanyarajendran', 'buzzdreamz', 'rsriram9',
#        'news24tvchannel', 'NewsNationTV', 'vik21_yadav', '_YogendraYadav',
#        'itisprashanth', 'orfonline', 'saikatd', 'MrsGandhi',
#        'EconomicTimes', 'renu_18', 'smkoneru', 'airnewsalerts',
#        'India__143', 'thetribunechd', 'iSirArnab', 'indiawestcanad1',
#        'VaayuFest', 'Kumar_Ke5hav', 'newslaundry', 'DhongiMonk',
#        'NewsroomPostCom', 'KunalChoudhary_', 'harishmenon',
#        'sureshpprabhu', 'silarindam', 'Yogeshg1977', 'anilkapur_',
#        'FinancialXpress', 'sboi', 'Djjpn', 'AhmedLovesSRK', 'AamAdmy',
#        'SangitaSri', 'vinodkapri', 'friendscongress', 'Ikumar7',
#        'AmitHPanchal', 'Leopard212', 'CriminalSingh', 'Ind_Arya',
#        'abhijitmajumder', 'PeninsulaQatar', 'YesIamSaffron',
#        'IndiaTodayFLASH', 'bharat_builder', 'webcrawlerw', 'TheQuint',
#        'kanimozhi', 'bitcoinagile', 'BharatPolls', 'devyanidilli',
#        'thenewsminute', 'MICA_Ahmedabad', 'Gravim71', 'DailyO_',
#        'AliyaNazki', 'ndtv', 'VishalDadlani', 'calamur', 'dilipvamanan',
#        'kapiljaink3', 'manojsirsa', 'ksinamdar', 'deepakurup',
#        'MinhazMerchant', 'RoflTeja', 'HPCL', 'kumarshyam', 'nidc13',
#        'ensine', 'sundeepshawarma', 'VijayThuse', 'BATOLEBAZI',
#        'KanchanGupta', 'ankitv', 'Modern_Scot', 'InfoMumbai', 'nsp2106',
#        'MobileChamps', 'Tan_Tripathi', 'RamkiXLRI', 'GSFNetwork',
#        'rupasubramanya', 'SomeBirdie', 'FrancoisF24', 'Oneindia',
#        'parulbajaj', 'ambkcsingh', 'ThinkersPad', 'GabbarSanghi',
#        'MahikaInfra', 'amritabhinder', 'HemanNamo', 'Retributions',
#        'BoNgDrEaMs', 'AdithyaMarri', 'AnthonySald', 'tv9gujarati',
#        'abdullah_0mar', 'CongressALL', 'firstpost', 'PTI_News',
#        'JaiveerShergill', 'DDNewsLive', 'ashwani_mahajan', 'maulinshah9',
#        'indiantweeter', 'JantaKaReporter', 'ScoopWhoop', 'NewsX',
#        'dilipkpandey', 'BawaHS', 'yespunjab', 'Chopsyturvey',
#        'ThisisBurhan', 'GetNewsd', 'AAPMaharashtra', 'neveraever',
#        'rranjaninc', 'KilaFateh', 'htTweets', 'ShelarAshish',
#        'buzzindelhi', 'vmlsanna9', 'DrNeelakshiGswm', 'POETICandFUNNY',
#        'SwoonyLoony', 'IndianExpress', 'No1kaChamcha', 'hstapanghosh',
#        'CNNnews18', 'SankarshanT', 'manavjivan', 'RameshwarAryaG',
#        'CMofKarnataka', 'Salilacharya', 'raggedtag', 'KartikeyaTanna',
#        'rjraunac', 'HusainRif', 'hvgoenka', 'ModifyingNation',
#        'ConversationUK', 'Inshal07', 'divyajn07', 'NewIndianXpress',
#        'MisaBharti', 'THComment', 'techcirclein', 'balamy', 'sonaliranade',
#        'navinkhaitan', 'jaiprakashshah2', 'BreakingNewsCEO',
#        'CholericCleric', 'thebobbydeoll', 'pradeepsethi', 'vdehejia',
#        '_RavinderSingh_', 'awasthis', 'SirJadeja', 'aartic02',
#        'PadmajaJoshi', 'ranganaathan', 'loosebool', 'MilanV',
#        'brijmohanJi', 'varundatta2u', 'Sheela__Singh', 'Awhadspeaks',
#        's_navroop', 'StackorStarvDJS', 'TimesNow', 'Breathedreamgo',
#        'TOIEntertain', 'BoringPortal', 'periyakulam', 'amworldtodaypm',
#        'Jansatta', 'ANI_news', 'RahulEaswar', 'timesofindia', 'roshan_b',
#        'NotSoSnob', 'girishjohar', 'kailashwg', 'TruthOfGujarat',
#        'Gotham3', 'babumoshoy', 'harish_purohit', 'AdvaitaKala',
#        'rssurjewala', 'adarshshastri', 'PersonalEscrito', 'join2manish',
#        'samirsaran', 'brumbyOz', 'YRDeshmukh', 'DaaruBaazMehta',
#        'steamintech', 'livemint', 'DILIPtheCHERIAN', 'hindustanse',
#        'KiranKS', 'IndiaToday', 'official_nagar', 'RDATT26', 'Navrang',
#        'ParagRudani', 'SalmanSoz', 'aparanjape', 'varshasinghmcx',
#        '_sabanaqvi', 'Satishshekar', 'itimestweets', 'down2earthindia',
#        'indiatvnews', 'AsCorrespondent', 'eleadersspeak', 'iKabirBedi',
#        '_garrywalia', 'NITIAayog', 'ParagDr', 'DrSunitaMishra', 'Joydas',
#        'udayavani_web', 'nihahs24', 'RealAmitBagaria', 'noconversion',
#        'sardesairajdeep', 'NewspointTv', 'parakala', 'arjunrammeghwal',
#        'Nikstrade', 'HaryanaTweets', 'aaprohit', 'vijaita', 'radharaju18',
#        'dineshgrao', 'romanaisarkhan', 'anaggh', 'shaanhaider',
#        'Sanju_Verma_', 'GautamGhosh', 'bedivikas82', 'bansode_sunny',
#        'telanganafacts', 'mazhar_jafri', 'HTPunjab', 'rajeev_mp',
#        'milligazette', 'SurajMNHegde', 'kunalgupta07', 'vijayrupanibjp',
#        'Ish_Bhandari', 'MustafaZoha', 'calestous', 'dustyplanet', 'tunkuv',
#        'dhaliwalmk', 'prayag', 'sekartweets', 'sidhuwrites',
#        'Myth_Busterz', 'ashokgehlot51', 'Meetasengupta', 'AgarwalGyan',
#        'Being_Humor', 'BrainandMoney', 'amishra77', 'AnkitLal',
#        'barandbench', 'LillyMaryPinto', 'Devinder_Sharma',
#        'TheDeccanHerald', 'itzmebobbydeol', 'mridula2c', 'SaundiD',
#        'MPCC_Official', 'Akashtv1', 'LavKrTiwari', 'muntaziraapka',
#        'SwarupPhD', 'MichaelKugelman', 'meerasanyal', 'ArvindGaur',
#        'womensworldbnkg', 'edemocracyworld', 'laimacha', 'SV99999',
#        'otvnews', 'Callum_Thomas', 'tajmahalfoxtrot', 'jayamrutia07',
#        'ETMarkets', 'digitalKapil_', 'NaIna0806', 'Outlookindia',
#        'kavita_krishnan', 'NanOratoR', 'DelhiConnect', 'KPMGIndia', 'BTVI',
#        'nistula', 'GauravPandhi', 'barbarindian', 'bainjal', 'ET_Wealth',
#        'indian_ordinary', 'drramansingh', 'TheWeekLive', 'sanjaynirupam',
#        'Wiseguy70', 'jalajboy', 'ghoshworld', 'GurpreetKChadha',
#        'twilightfairy', 'Amit_smiling', 'rakeshgadde', 'Swt_Sadhana',
#        'raisevoicepolls', 'VAyakin', 'AMK_IN', 'M_Lekhi', 'Rjsayema',
#        'SitaramYechury', 'prasannavishy', 'PMOIndia_RC', 'bsindia',
#        'sankrant', 'thewire_in', 'bhupendrachaube', 'Kurmanath',
#        'RituRathaur', 'ShirishKunder', 'TV9Telugu', 'panku_',
#        'spbhattacharya', 'Smita_Sharma', 'rajudasonline', 'AOLSwamiji',
#        'ADTSinghSharma', 'bhaweshjha', 'CashAlternative', 'KanakManiDixit',
#        'Kar_Sevak', 'HusnKaHathiyar', 'ramanmalik', 'Komal_Indian',
#        'DasBolshevik', 'karmanomad', 'RatiranjanSS', 'dhaval241086',
#        'jitenderkhalsa', 'DrJwalaG', 'ashu3page', 'sanjayuvacha',
#        'IMAPictures', 'chitraSD', '21century_kant', 'Chhabiy', 'supratick',
#        'Veidehii', 'sanjivbhatt', 'apssara2013', 'imransolanki313',
#        'giniromet', 'Mamata_maa', 'abntelugutv', 'NilimDutta',
#        'brajeshlive', 'lolmaal', 'quizderek', 'kauserseema', 'SouleFacts',
#        'cpimspeak', 'HinduRajyam', 'GunjanOfficial', 'ShashiTharoor',
#        'CNBCTV18Live', 'CollChris', 'RoflReporter', 'somkritya',
#        'MaheishGirri', 'businessline', 'nehadixit123', 'maheshmurthy',
#        'HasnaZarooriHai', 'PawanDurani', 'e4mtweets', 'DailyTimes_DT',
#        'Jaitwits', 'GitaSKapoor', 'katamulgi', 'kappansky', 'jigar_dhulla',
#        'TheVivekTomar', 'alamgirizvi', 'vikaskyogi', 'CapitalVia',
#        'irajdeep', 'ZeeBusiness', 'CNBCTV18News', 'premchandsayz',
#        'AshwiniBJP', 'TeluguFilmBuzz', 'Iffidel', 'HuffPostIndia',
#        'TekiRosh', 'ShopClues', 'shakkuiyer'], dtype=object)
